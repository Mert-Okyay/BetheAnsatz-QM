# %% [markdown]
# # Closed XXZ Chain Bethe Ansatz Eigenstates on a Quantum Computer
# $$\newcommand{\ket}[1]{\left|{#1}\right\rangle}$$

# %%
# qiskit 0.29.0

from qiskit import *
from math import pi, acos, sqrt, comb, cos, sin
import numpy as np

from qiskit.circuit.library.standard_gates import RYGate,XGate
from qiskit.circuit import Parameter

# %%
np.set_printoptions(suppress=True)

# %% [markdown]
# First, we start by defining a function that runs the usual simulator and gives the simulated results, to test what we should get

# %%
def test_circ(circ, qReg, cReg):
    from qiskit import Aer

    simulator = Aer.get_backend('qasm_simulator')

    # We've set the number of shots (repeats) of the circuit
    # to be 1024, which is the default value
    circ.measure(qReg,cReg)
    job_sim = execute(circ, backend=simulator, shots=10240)

    # Grab the results from the job
    result_sim = job_sim.result()

    counts_sim = result_sim.get_counts(circ)
    print(counts_sim)

    # Plot a histogram of the results
    from qiskit.visualization import plot_histogram
    return plot_histogram(counts_sim)

# %% [markdown]
# ## Step 1: Generating the dicke states $\ket{D_{L,M}}$, by Bärtschi and Eidenbenz (arXiv:1904.07358, 2019)

# %% [markdown]
# ### Ch 2.2) Explicit Construction of $ SCS_{n k}$

# %% [markdown]
# We will try to construct the algorithm by creating circuits for each piece of the puzzles.

# %% [markdown]
# #### Ch 2.2.1) Explicit Construction of the 2-qubit gate (i) of  $ SCS_{n,k}$

# %% [markdown]
# Initially, we try to replicate the simple 2-qubit component of the $SCS_{n,k}$ gate (i) on page 6

# %%
ancilla_multiplier = 1
n = 2*ancilla_multiplier

# create n quantum registers, one for each qubit
q=QuantumRegister(n)

# create n corresponding classical registers (needed for storing measurement results)
c=ClassicalRegister(n)

# create a quantum circuit with these registers.
# circuit type: 2-qubit gate (i)
scs2 = QuantumCircuit(q,c)

last = n-1
first = 0

#input gates(00: both commented; 1/sqrt(2) (01 + 10), comment either; 11, comment none)
#scs2.x(q[last-1])
scs2.x(q[last])

# (i) gate
scs2.cx(q[last-1], q[last])
scs2.cry(2*acos(sqrt(1/n)),q[last], q[last-1])
scs2.cx(q[last-1], q[last])

# measurement gates
scs2.barrier()
scs2.measure(q,c)

scs2.draw(output='mpl', initial_state=True)

#test_circ(scs2)

# %% [markdown]
# #### Ch 2.2.2) Explicit Construction of  the 3-qubit gate (ii) of $ SCS_{n k}$

# %% [markdown]
# Then, we construct the 3-qubit component of the $SCS_{n,k}$ gate (ii) on page 6

# %%
ancilla_multiplier = 1
n = 5*ancilla_multiplier

l = 3

# create 3 quantum registers, one for each qubit
q=QuantumRegister(n)

# create 3 corresponding classical registers (needed for storing measurement results)
c=ClassicalRegister(n)

# create a quantum circuit with these registers.
# circuit type: 2-qubit gate (i)
scs2 = QuantumCircuit(q,c)

last = n-1
first = 0

#input gates(00: both commented; 1/sqrt(2) (01 + 10), comment either; 11, comment none)
#scs2.x(q[last-1])
#scs2.x(q[last])

# (ii) gate
scs2.cx(q[last-l], q[last])

a = 2*acos(sqrt(l/n)) # Parameter('a') # You can replace a with your choice of angle here
CCRY=RYGate(a).control(2)
scs2.append(CCRY,[last, last-l+1,last-l])


scs2.cx(q[last-l], q[last])

# measurement gates
scs2.barrier()
scs2.measure(q,c)

scs2.draw(output='mpl', initial_state=True)

#test_circ(scs2)

# %%
def remove_M(circ):
    i = 0
    while i < (len(circ.data)):
        if i>=len(circ.data):
            break
        if "Measure" in str(circ.data[i][0]):
            circ.data.pop(i)
            i = i-1
        i = i+1

# %%
remove_M(scs2)
scs2.draw('mpl')

# %% [markdown]
# #### Ch 2.2.1) Explicit Construction of  the $ U_{n k}$ on n qubits to obtain the Dicke state $\ket{D_{L,M}}$

# %%
# creating equal-weight superposition of all n-qubit states with 
# Hamming Weight k (i.e. all strings of length n with exactly k 1s over a binary
# alphabet

# or in physics lingo

# creating equal-weight superpositions of M down spins, permuted over a length L spin chain

# should have L choose M distinct states


# how many ancillas you want
ancilla = 0
# how many main qubits you want
main = 4

L = main + ancilla


# how many down spins you want
M = 2

print("should have "+ str(comb(L, M)) + " states")

# create L quantum registers, one for each spin on the chain
q = QuantumRegister(L)

# create L corresponding classical registers (for measurement )
c = ClassicalRegister(L)

# create a quantum circuit with these registers.
# circuit type: Dicke state generator
dicke = QuantumCircuit(q,c)

last = L-1
first = 0

# initializing the |1> qubits:

for i in range(first, M):
    dicke.x(q[last-i])

for i in range(first, last):
    # (i) gate
    dicke.cx(q[last-1-i], q[last-i])
    dicke.cry(2*np.arccos(np.sqrt(1/(L-i))),q[last-i], q[last-1-i])
    dicke.cx(q[last-1-i], q[last-i])
    if L-i == M:
        # decrease M by 1, if SCS_{M,M} would be reached next
        M = M - 1
    #(ii) gate(s)
    for j in range(0,M-1):
        
        dicke.cx(q[(last-1-i)-1-j], q[last-i])
        ## Constructing the double-controlled Ry gate
        a = 2*np.arccos(np.sqrt((j+2)/(L-i))) # Parameter('a') # You can replace a with your choice of angle here
        CCRY=RYGate(a).control(2)
        dicke.append(CCRY,[last-i, last-i-1-j,(last-1-i)-1-j])
        
        dicke.cx(q[(last-1-i)-1-j], q[last-i])
        
#    dicke.barrier()

    
# measurement gates
#dicke.measure(q,c)

dicke.draw(output='mpl', initial_state=True)
# Out:
# should have 6 states

# %%
test_circ(dicke,q,c)
# Out:
# {'0011': 1717, '1100': 1690, '0110': 1700, '1010': 1708, '1001': 1710, '0101': 1715}

# %%
remove_M(dicke)
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0'*(L))
state = sv.evolve(dicke)
state.data[0:2**L]
# Out:
# array([ 0.        +0.j,  0.        +0.j,  0.        +0.j,  0.40824829+0.j,
#         0.        +0.j,  0.40824829+0.j,  0.40824829+0.j,  0.        +0.j,
#         0.        +0.j,  0.40824829+0.j,  0.40824829+0.j,  0.        +0.j,
#         0.40824829+0.j,  0.        +0.j,  0.        +0.j, -0.        +0.j])

# %% [markdown]
# Exactly like the Eidenbenz paper.

# %% [markdown]
# ## Step 2: Constructing the permutation ancillas $\left(\frac{1}{\sqrt{M !}} \sum_{P} A_{P} \otimes_{j=M}^{1}|P j\rangle_{p}\right)$

# %%
def ASWAP(circuit, k, target1, target2):
    circuit.cx(q[target2],q[target1])
    circuit.rz(-pi,q[target2])
    circuit.ry(-2.53,q[target2])
    circuit.cx(q[target1],q[target2])
    circuit.ry(2.53,q[target2])
    circuit.rz(pi,q[target2])
    circuit.cx(q[target2],q[target1])

# %% [markdown]
# First, construct the circuit on page 5 of 2103.13388.pdf to understand the algorithm

# %%
M = 3

# create 3 quantum registers, one for each qubit
q=QuantumRegister(M**2)

# create 3 corresponding classical registers (needed for storing measurement results)
c=ClassicalRegister(M**2)

# create a quantum circuit with these registers
chain = QuantumCircuit(q,c)

# NOT gates on q[0] and q[1]
chain.x(q[0])
chain.x(q[4])


# double-controlled-NOT (Toffoli) gate; controls={q[0],q[1]};  target=q[2]
# toffoli.ccx(q[0], q[1], q[2])

# Construct ASWAP gates

# ASWAP k=0
## cNOT (controlled-NOT) gate; control=q[0];  target=q[1]
chain.cx(q[4],q[1])


## R_z qubit rotation gate; target=q[4], angle = -pi
chain.rz(-pi,q[4])


## R_y qubit rotation gate; target=q[4], angle = -3*pi/4
chain.ry(-3*pi/4,q[4])



chain.cx(q[1],q[4])


## R_y qubit rotation gate; target=q[4], angle = -3*pi/4
chain.ry(3*pi/4,q[4])

## R_z qubit rotation gate; target=q[4], angle = -pi
chain.rz(pi,q[4])



## cNOT (controlled-NOT) gate; control=q[0];  target=q[1]
chain.cx(q[4],q[1])


# cSWAP (controlled-SWAP gate); control = q[1], target=(q[0], q[3])
chain.cswap(q[1],q[0],q[3])

#chain.cp(pi,q[0], q[1])
#chain.barrier()



chain.x(q[8])

#ASWAP(chain, 0, 5, 8)
chain.cx(q[8],q[5])
chain.rz(-pi,q[8])
chain.ry(-2.53,q[8])
chain.cx(q[5],q[8])
chain.ry(2.53,q[8])
chain.rz(pi,q[8])
chain.cx(q[8],q[5])


chain.cswap(q[5],q[3],q[6])
chain.cswap(q[5],q[4],q[7])
# Construct ASWAP gates

## cNOT (controlled-NOT) gate; control=q[0];  target=q[1]
chain.cx(q[5],q[2])

## R_z qubit rotation gate; target=q[4], angle = -pi
chain.rz(-pi,q[5])

## R_y qubit rotation gate; target=q[4], angle = -3*pi/4
chain.ry(-3*pi/4,q[5])

chain.cx(q[2],q[5])

## R_y qubit rotation gate; target=q[4], angle = -3*pi/4
chain.ry(3*pi/4,q[5])

## R_z qubit rotation gate; target=q[4], angle = -pi
chain.rz(pi,q[5])

## cNOT (controlled-NOT) gate; control=q[0];  target=q[1]
chain.cx(q[5],q[2])


# cSWAPs (controlled SWAP)
chain.cswap(q[2],q[0],q[3])
chain.cswap(q[2],q[1],q[4])

chain.barrier()
#measurement gates
#chain.measure(q, c)

# %%
chain.draw(output='mpl', initial_state=True)

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0'*(M**2))
state = sv.evolve(chain)
state.data[0:2**(M**2)]
# Out:
# array([ 0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.4093673 +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.4093673 +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.4093673 +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.4093673 +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.40600102+0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.40600102-0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j, -0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        -0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j,
#         0.        +0.j,  0.        +0.j,  0.        +0.j,  0.        +0.j])

# %%
test_circ(chain,q,c)
# Out:
# {'010100001': 1687, '100001010': 1619, '001010100': 1689, '010001100': 1762, '100010001': 1717, '001100010': 1766}

# %% [markdown]
# ### Executing the circuit on the local qasm simulator

# %%
from qiskit import Aer

simulator = Aer.get_backend('qasm_simulator')

# %%
# We've set the number of shots (repeats) of the circuit
# to be 1024, which is the default value
chain.measure(q,c)
job_sim = execute(chain, backend=simulator, shots=10240)

# %%
# Grab the results from the job
result_sim = job_sim.result()

# %%
counts_sim = result_sim.get_counts(chain)
print(counts_sim)
# Out:
# {'100010001': 1721, '010100001': 1655, '100001010': 1704, '010001100': 1679, '001010100': 1791, '001100010': 1690}

# %%
# Plot a histogram of the results
from qiskit.visualization import plot_histogram
plot_histogram(counts_sim)

# %% [markdown]
# # For arbitrary M

# %%
def index(subregister, qubit):
    return subregister*M+qubit

from math import asin

def angle(k):
    return asin(1/sqrt(k+2))

from qiskit.extensions import UnitaryGate

def ASWAP2(circuit, k, target1, target2):
    gate = [
        [1,      0,              0,        0],
        [0, 1/sqrt(k+2), sqrt((k+1)/(k+2)),0],
        [0, sqrt((k+1)/(k+2)),-1/sqrt(k+2),0],
        [0,     0,              0,        1]]
    circuit.unitary(gate,[target1, target2])
    
def ASWAP3(circuit, k, target1, target2):
    gate = [
        [1,      0,              0,        0],
        [0, cos(angle(k)), sin(angle(k)),0],
        [0, sin(angle(k)),-cos(angle(k)),0],
        [0,     0,              0,        1]]
    circuit.unitary(gate,[target1, target2])

# %%
M = 2

# create 3 quantum registers, one for each qubit
q=QuantumRegister(M**2)

# create 3 corresponding classical registers (needed for storing measurement results)
c=ClassicalRegister(M**2)

# create a quantum circuit with these registers
chain2 = QuantumCircuit(q,c)

k = 0

# NOT gate on the zeroeth qubit to obtain the 0 subregister.
chain2.x(q[k])

### ITERATION k=0 ###
for k in range(0, M-1):

    # NOT gate on the k+1 qubit of the k+1 subregister
    chain2.x(q[index(k+1,k+1)])

    # partial swap loop

    for i in range(0, k+1):
        # Construct ASWAP gates
        ASWAP3(chain2, k-i, index(k-i,k+1), index(k+1-i,k+1))

        # cSWAPs (controlled-SWAP gate); control = q[1], target=(q[0], q[3])
        # syntax: chain.cswap(q[1],q[0],q[3])

        # Iterate from: control at subregister k, qubit k+1 ---> control = q[index(k,k+1)]
        #                                             targets: (q[index(k,l)], q[index(k+1,l)]) with l =0 to l = k-1

        for l in range(0, k+1):
            chain2.cswap(q[index(k-i,k+1)], q[index(k-i,l)], q[index(k+1-i,l)])
            #chain2.cp(bethePhase,q[index(k-i,l)], q[index(k-i,k+1)])
        chain2.barrier()
    chain2.barrier()
#chain2.barrier()

# chain2.barrier()
# for k in reversed(range(0, M-1)):

#     # partial swap loop

#     for i in reversed(range(0, k+1)):
#         # cSWAPs (controlled-SWAP gate); control = q[1], target=(q[0], q[3])
#         # syntax: chain.cswap(q[1],q[0],q[3])

#         # Iterate from: control at subregister k, qubit k+1 ---> control = q[index(k,k+1)]
#         #                          targets: (q[index(k,l)], q[index(k+1,l)]) with l =0 to l = k-1

#         for l in reversed(range(0, k+1)):
#             chain2.cswap(q[index(k-i,k+1)], q[index(k-i,l)], q[index(k+1-i,l)])
#             #bethe.cp(bethePhase,q[index(k-i,l)], q[index(k-i,k+1)])
#             #plug in the bethe roots (real) here
            
#         # Construct ASWAP gates
#         ASWAP2(chain2, k-i, index(k+1-i,k+1),index(k-i,k+1))
            
    
#     # NOT gate on the k+1 qubit of the k+1 subregister
#     chain2.x(q[index(k+1,k+1)])
    
# #NOT gate on the 0 qubit of the 0 subregister
# chain2.x(q[index(0,0)])

# measurement gates
chain2.measure(q, c)

# %%
#chain2.basis = chain2.decompose()
remove_M(chain2)

# %%
chain2.draw(output='mpl', initial_state=True)

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0'*(M**2))
state = sv.evolve(chain2)
output = state.data[0:2**(M**2)]

# %%
for i in range(len(output)):
    print(i, output[i])
# Out:
# 0 0j
# 1 0j
# 2 0j
# 3 0j
# 4 0j
# 5 0j
# 6 (0.7071067811865475+0j)
# 7 0j
# 8 0j
# 9 (-0.7071067811865477+0j)
# 10 0j
# 11 0j
# 12 0j
# 13 0j
# 14 0j
# 15 0j

# %%
from qiskit import Aer

simulator = Aer.get_backend('qasm_simulator')

# %%
# We've set the number of shots (repeats) of the circuit
# to be 1024, which is the default value
#measurement gates
chain2.measure(q, c)
job_sim = execute(chain2, backend=simulator, shots=1024000)

# %%
# Grab the results from the job
result_sim = job_sim.result()

# %%
counts_sim = result_sim.get_counts(chain2)
print(counts_sim)
# Out:
# {'010001100': 170559, '001010100': 170602, '100010001': 170680, '010100001': 170993, '100001010': 170620, '001100010': 170546}

# %%
# Plot a histogram of the results
from qiskit.visualization import plot_histogram
plot_histogram(counts_sim)

# %% [markdown]
# ## Step 3 and 4: The faucet method and reversing the permutations

# %% [markdown]
# First we need to be able to combine the dicke and the permutatuion circuits to implement the faucet method. Let us proceed step by step.

# %% [markdown]
# ### 3) Preliminary functions

# %%
def index(subregister, qubit):
    return subregister*M+qubit

from math import atan, cos, sin, asin

def angle(k):
    return asin(1/sqrt(k+2))

from qiskit.extensions import UnitaryGate

def ASWAP2(circuit, k, target1, target2):
    gate = [
        [1,      0,              0,        0],
        [0, 1/sqrt(k+2), sqrt((k+1)/(k+2)),0],
        [0, sqrt((k+1)/(k+2)),-1/sqrt(k+2),0],
        [0,     0,              0,        1]]
    circuit.unitary(gate,[target1,target2])

def ASWAP3(circuit, k, target1, target2):
    gate = [
        [1,      0,              0,        0],
        [0, cos(angle(k)), sin(angle(k)),0],
        [0, sin(angle(k)),-cos(angle(k)),0],
        [0,     0,              0,        1]]
    circuit.unitary(gate,[target1, target2])

def theta(ki,kj):
    d = (ki-kj)/2
    s = (ki+kj)/2
    return 2*atan((delta*sin(d)/(delta*cos(d)-cos(s))))

# %% [markdown]
# ### 3.2) Parameters of the Bethe states we want

# %%
# creating equal-weight superposition of all n-qubit states with 
# Hamming Weight k (i.e. all strings of length n with exactly k 1s over a binary
# alphabet

# or in physics language

# creating equal-weight superpositions of M down spins, permuted over a length L spin chain

#anisotropy parameter
delta = 1

# should have L choose M distinct states

# how many ancillas you want
ancilla = 0
# how many main qubits you want
main = 6

L = main + ancilla


# how many down spins you want
init_M = 3

M = init_M

print("should have "+ str(comb(L, M)) + " states")

# enter the bethe momenta
# later, calculate this in python

# known ones:  L=4, M=2:  bethek =  [2*pi/3, 4*pi/3]
#              L=6, M=3:  bethek = [4.56042, pi, 1.72277]

bethek =  [4.56042, pi, 1.72277]
bethek.sort()

if len(bethek) != max(M, L-M):
    print("length of momentum array is incorrect")
# Out:
# should have 20 states

# %% [markdown]
# ### 3.3) Creating the circuit

# %%
# create L quantum registers, one for each spin on the chain 
                                #plus M^2 for the permutation ancillas
                                #plus M faucet ancillas 
                                #plus 1 work qubit
qSys = QuantumRegister(L)
qPerm = QuantumRegister(M**2)
qFaucet = QuantumRegister(M)
#qWork = QuantumRegister(1)

# create corresponding classical registers (for measurement )
cSys = ClassicalRegister(L)
cPerm = ClassicalRegister(M**2)
cFaucet = ClassicalRegister(M)
#cWork = ClassicalRegister(1)

# create a quantum circuit with these registers.
# circuit type: Bethe Eigenstate generator
#bethe = QuantumCircuit(qSys, qPerm, qFaucet, qWork, cSys, cPerm, cFaucet, cWork)
bethe = QuantumCircuit(qSys, qPerm, qFaucet, cSys, cPerm, cFaucet)

# %% [markdown]
# ### 3.3.1) Step 1: Dicke States

# %%
#### DICKE STATES ####

first = 0
last = L-1


# initializing the 1 qubits:

for i in range(first, M):
    bethe.x(qSys[last-i])

for i in range(first, last):
    # (i) gate
    bethe.cx(qSys[last-1-i], qSys[last-i])
    bethe.cry(2*acos(sqrt(1/(L-i))),qSys[last-i], qSys[last-1-i])
    bethe.cx(qSys[last-1-i], qSys[last-i])
    if L-i == M:
        # decrease M by 1, if SCS_{M,M} would be reached next
        M = M - 1
    #(ii) gate(s)
    print(M)
    for j in range(0,M-1):
        print(j)
        bethe.cx(qSys[(last-1-i)-1-j], qSys[last-i])
        ## Constructing the double-controlled Ry gate
        a = 2*acos(sqrt((j+2)/(L-i))) # Parameter('a') # You can replace a with your choice of angle here
        CCRY=RYGate(a).control(2)
        bethe.append(CCRY,[last-i, last-i-1-j,(last-1-i)-1-j])
        
        bethe.cx(qSys[(last-1-i)-1-j], qSys[last-i])
        
bethe.draw('mpl')
# Out:
# 3
# 0
# 1
# 3
# 0
# 1
# 3
# 0
# 1
# 2
# 0
# 1

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0'*(L+M**2+M))
state = sv.evolve(bethe)
state.data[0:2**L]
# Out:
# array([ 0.       +0.j,  0.       +0.j,  0.       +0.j,  0.       +0.j,
#         0.       +0.j,  0.       +0.j,  0.       +0.j,  0.2236068+0.j,
#         0.       +0.j,  0.       +0.j,  0.       +0.j,  0.2236068+0.j,
#         0.       +0.j,  0.2236068+0.j,  0.2236068+0.j,  0.       +0.j,
#        -0.       +0.j,  0.       +0.j,  0.       +0.j,  0.2236068+0.j,
#         0.       +0.j,  0.2236068+0.j,  0.2236068+0.j,  0.       +0.j,
#         0.       +0.j,  0.2236068+0.j,  0.2236068+0.j,  0.       +0.j,
#         0.2236068+0.j,  0.       +0.j,  0.       +0.j,  0.       +0.j,
#        -0.       +0.j,  0.       +0.j,  0.       +0.j,  0.2236068+0.j,
#         0.       +0.j,  0.2236068+0.j,  0.2236068+0.j,  0.       +0.j,
#         0.       +0.j,  0.2236068+0.j,  0.2236068+0.j,  0.       +0.j,
#         0.2236068+0.j,  0.       +0.j,  0.       +0.j,  0.       +0.j,
#         0.       +0.j,  0.2236068+0.j,  0.2236068+0.j,  0.       +0.j,
#         0.2236068+0.j,  0.       +0.j,  0.       +0.j,  0.       +0.j,
#         0.2236068+0.j,  0.       +0.j,  0.       +0.j, -0.       +0.j,
#         0.       +0.j, -0.       +0.j,  0.       +0.j,  0.       +0.j])

# %% [markdown]
# This is the correct Dicke state, verified by mathematica.

# %% [markdown]
# ### 3.3.2) Step 2: Permutation ancillas

# %%
### THE PERMUTATION ANCILLAS ####

M = init_M

k = 0

#NOT gate on the zeroeth qubit to obtain the 0 subregister.
bethe.x(qPerm[index(0,k)])


for k in range(0, M-1):

    # NOT gate on the k+1 qubit of the k+1 subregister
    bethe.x(qPerm[index(k+1,k+1)])

    # partial swap loop

    for i in range(0, k+1):
        # Construct ASWAP gates
        ASWAP3(bethe, k-i, index(k-i,k+1)+L, index(k+1-i,k+1)+L)

        # cSWAPs (controlled-SWAP gate); control = q[1], target=(q[0], q[3])
        # syntax: chain.cswap(q[1],q[0],q[3])

        # Iterate from: control at subregister k, qubit k+1 ---> control = q[index(k,k+1)]
        #                                         targets: (q[index(k,l)], q[index(k+1,l)]) with l =0 to l = k-1

        for l in range(0, k+1):
            bethe.cswap(qPerm[index(k-i,k+1)], qPerm[index(k-i,l)], qPerm[index(k+1-i,l)])
        for l in range(0, k+1):
            bethe.cp(theta(bethek[k+1],bethek[k-i])+pi,qPerm[index(k-i,k+1)],qPerm[index(k+1-i,l)])
            #plug in the bethe roots (real) here
            
bethe.draw('mpl')

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0'*(L+M**2+M))
state = sv.evolve(bethe)
state.data[2**L:2**(L+M**2)]
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j])

# %% [markdown]
# ### 3.3.3) Step 3: Faucet Method to push the phases

# %%
#### FAUCET ANCILLAS ####

dickeFirst = first
dickeLast = last

first = 0
last = first+M

#initialize the faucets to |1>

for i in range(first, last):
    bethe.x(qFaucet[i])
    
bethe.barrier()

edge = L-M

for i in range(dickeFirst, dickeLast+1):
    j = last-1
    while j >= first:
#        print(j-i, dickeLast+1-i)
        if (j <= i and i<=edge) or (j>= (i-edge) and (dickeLast+1-i)<=edge):
            if (j-1)%M == last-1:
                noX = True
            else: 
                noX = False
            if M > 2:
                CCCX=XGate().control(3)
                bethe.x(qFaucet[((j-1)%M)]) if not noX  else ""                 
                bethe.append(CCCX, [i, ((j-1)%M)+L+M**2, ((j+1)%M)+L+M**2,(j%M)+L+M**2])
                bethe.x(qFaucet[((j-1)%M)]) if not noX  else ""   
            elif M == 2: 
                CCCX=XGate().control(2)
                bethe.x(qFaucet[((j+1)%M)]) if not noX    else ""  
                bethe.append(CCCX, [i, ((j+1)%M)+L+M**2,(j%M)+L+M**2])
                bethe.x(qFaucet[((j+1)%M)]) if not noX else ""   
        j = j - 1
    bethe.barrier()

    for j in range(first, last):
        for l in range(index(j,0),index(j,M)):
            bethe.cp(bethek[l%M], qPerm[l], qFaucet[j])

# %%
bethe.draw('mpl')

# %% [markdown]
# ### 3.3.4) Step 4) Reversing the Permutation step

# %%
# ### REVERSING THE PERMUTATION ANCILLAS ###

# Simply by reversing the loop iterations and also the placements of the
# code lines, one can exactly reverse the permutation step

bethe.barrier()
for k in reversed(range(0, M-1)):

    for i in reversed(range(0, k+1)):

        # Iterate from: control at subregister k, qubit k+1 ---> control = q[index(k,k+1)]
        #                          targets: (q[index(k,l)], q[index(k+1,l)]) with l =0 to l = k-1

        for l in reversed(range(0, k+1)):
            bethe.cswap(qPerm[index(k-i,k+1)], qPerm[index(k-i,l)], qPerm[index(k+1-i,l)])

            
        # Construct ASWAP gates
        # note that we add plus L at the end of index because the circuit.append 
        # function indexes through all qubits, not in the subregisters as we 
        # defined
        ASWAP3(bethe, k-i, index(k-i,k+1)+L, index(k+1-i,k+1)+L)
            
    
    # NOT gate on the k+1 qubit of the k+1 subregister
    bethe.x(qPerm[index(k+1,k+1)])
    
#NOT gate on the 0 qubit of the 0 subregister
bethe.x(qPerm[index(0,0)])

# %%
bethe.draw('mpl')

# %%
from qiskit.quantum_info import Statevector
sv = Statevector.from_label('0'*(L+M**2+M))
state = sv.evolve(bethe)
state.data[0:2**L]
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j])

# %%
state = sv.evolve(bethe)
state
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2))

# %%
state.data[0:2**L]
# Out:
# array([ 0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        , -0.20412415-0.35355339j,
#         0.        +0.j        ,  0.10206207+0.1767767j ,
#        -0.20412415-0.35355339j,  0.        +0.j        ,
#         0.        +0.j        ,  0.10206207+0.1767767j ,
#         0.10206207+0.1767767j ,  0.        +0.j        ,
#        -0.20412415-0.35355339j,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ])

# %%
from qiskit.quantum_info import Statevector

# %%
sv = Statevector.from_label('0'*(L+M**2+M))

# %%
state = sv.evolve(bethe)
state
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2))

# %%
state.data[0:2**L]
# Out:
# array([ 0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        , -0.20412415+0.35355339j,
#         0.        +0.j        ,  0.10206207-0.1767767j ,
#        -0.20412415+0.35355339j,  0.        +0.j        ,
#         0.        +0.j        ,  0.10206207-0.1767767j ,
#         0.10206207-0.1767767j ,  0.        +0.j        ,
#        -0.20412415+0.35355339j,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ])
